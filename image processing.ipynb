# %%
#pip install -U scikit-image

# %%
import matplotlib.pyplot as plt
import numpy as np
import skimage as ski

# %%
import skimage.data as data

# List all attributes of the skimage.data module that are callable (i.e., functions)
available_images = [name for name in dir(data) if callable(getattr(data, name))]

print(available_images)
# Out:
# ['astronaut', 'binary_blobs', 'brain', 'brick', 'camera', 'cat', 'cell', 'cells3d', 'checkerboard', 'chelsea', 'clock', 'coffee', 'coins', 'colorwheel', 'download_all', 'eagle', 'file_hash', 'grass', 'gravel', 'horse', 'hubble_deep_field', 'human_mitosis', 'immunohistochemistry', 'kidney', 'lbp_frontal_face_cascade_filename', 'lfw_subset', 'lily', 'logo', 'microaneurysms', 'moon', 'nickel_solidification', 'page', 'palisades_of_vogt', 'protein_transport', 'retina', 'rocket', 'shepp_logan_phantom', 'skin', 'stereo_motorcycle', 'text', 'vortex']

# %%
images = (
    'brick',
    'camera',
)

# %%
from skimage.data import camera, brick

# %%
camera()
# Out:
# array([[200, 200, 200, ..., 189, 190, 190],
#        [200, 199, 199, ..., 190, 190, 190],
#        [199, 199, 199, ..., 190, 190, 190],
#        ...,
#        [ 25,  25,  27, ..., 139, 122, 147],
#        [ 25,  25,  26, ..., 158, 141, 168],
#        [ 25,  25,  27, ..., 151, 152, 149]], dtype=uint8)

# %%
camera().shape
# Out:
# (512, 512)

# %%
ski.io.imshow(camera());
# Out:
# /var/folders/dl/ms7s6rfs7mv0rpd5jy7c8h640000gn/T/ipykernel_97529/2972447129.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(camera());

# %%
ski.io.imshow(brick());
# Out:
# /var/folders/dl/ms7s6rfs7mv0rpd5jy7c8h640000gn/T/ipykernel_97529/4259059541.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(brick());

# %% [markdown]
# ### Custom Kernels

# %%
v_filter = [[-5, 0, 5], 
        [-0.5, 0, 0.5],
        [-5, 0, 5]]

# %%
def apply_filter(image, v_filter):
    
    # Get dimensions of the image
    width = image.shape[1]
    kw = len(v_filter)

    # Prepare output image
    output = [[0] * width for _ in range(width)]

    # Apply filter to the image
    for y in range(1, width - 1):
        for x in range(1, width - 1):
            sum_ = 0
            for v_filter_y in range(kw):
                for v_filter_x in range(kw):
                    val = image[y + v_filter_y - 1][x + v_filter_x - 1]
                    sum_ += v_filter[v_filter_y][v_filter_x] * val

            output[y][x] = sum_

    return np.array(output)

# %%
output = apply_filter(camera(), v_filter)
ski.io.imshow(output, cmap=plt.cm.gray);
# Out:
# /var/folders/dl/ms7s6rfs7mv0rpd5jy7c8h640000gn/T/ipykernel_97529/4051600693.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(output, cmap=plt.cm.gray);

# %%
output = apply_filter(brick(), v_filter)
ski.io.imshow(output, cmap=plt.cm.gray);
# Out:
# /var/folders/dl/ms7s6rfs7mv0rpd5jy7c8h640000gn/T/ipykernel_97529/350692724.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(output, cmap=plt.cm.gray);

# %%
h_filter = [[-0.5, -5, -0.5], 
        [0, 0, 0],
        [0.5, 5, 0.5]]

# %%
output = apply_filter(camera(), h_filter)
ski.io.imshow(output, cmap=plt.cm.gray);
# Out:
# /var/folders/dl/ms7s6rfs7mv0rpd5jy7c8h640000gn/T/ipykernel_97529/1379885296.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(output, cmap=plt.cm.gray);

# %%
output = apply_filter(brick(), h_filter)
ski.io.imshow(output, cmap=plt.cm.gray);
# Out:
# /var/folders/dl/ms7s6rfs7mv0rpd5jy7c8h640000gn/T/ipykernel_97529/4257186119.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(output, cmap=plt.cm.gray);
